# %%
import pickle
loaded_model=pickle.load(open("finalized_model_multiple_linear.sav",'rb'))

# %%
# Predict profit for a startup
new_startup = [[1234, 5678, 4565, True, False]]  # R&D, Admin, Marketing, State_Florida, State_New York
predicted_profit = loaded_model.predict(new_startup)
#print("Predicted Profit:", predicted_profit[0])
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predicted_profit
# Out:
# array([45234.07439563])
